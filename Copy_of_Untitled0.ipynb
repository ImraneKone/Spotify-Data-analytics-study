# %% [markdown]
# <a href="https://colab.research.google.com/github/ImraneKone/Spotify-Data-analytics-study/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data= pd.read_csv ('drive/MyDrive/tracks.csv')
Data.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
pd.isnull(Data).sum()
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %%
# to find the most popular song and the authors

sorted_popularity= Data.sort_values('popularity', ascending=False).head(10)
sorted_popularity
# Out:
#                            id                                    name  \
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 93803  7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 93804  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 92810  5QO79kh1waicV47BqGRL3g                         Save Your Tears
# 92811  6tDDoYIxWvMLTdKpjFkc1B                               telepatía
# 93805  7MAibcTli4IisCtbHKrGMh                     Leave The Door Open
# 92813  0VjIjW4GlUZAMYd2vXMi3b                         Blinding Lights
# 92814  6f3Slt0GbA2bPZlz0aIFXN                            The Business
# 92816  3FAJ6O0NOHQV8Mc5Ri6ENp                  Heartbreak Anniversary
# 92819  1xK1Gg9SxG8fy2Ya373oqb                                 Bandido
#
#        popularity  duration_ms  explicit  \
# 93802         100       198082         1
# 93803          99       242014         1
# 93804          98       132780         0
# ...

# %%
# To find the least popular songs

sorted_popularity= Data.sort_values('popularity', ascending=True).head(10)
sorted_popularity
# Out:
#                             id  \
# 546130  181rTRhCcggZPwP2TUcVqm
# 546222  0yOCz3V5KMm8l1T8EFc60i
# 546221  0y48Hhwe52099UqYjegRCO
# 546220  0xCmgtf9ka07hkZg3D6PaV
# 546219  0tBXS3VuCPX7KWUFH2nros
# 546218  0qrKnQtYDVJhKFAXTHYVS9
# 546217  0nqsDxOeKSwEzp3AUQAAqS
# 546216  0kGEdsxVLYjCdfxM9tbezd
# 546215  0bc3PUZurUUXrY7yqoOxjq
# 546214  0Wwm0ruSjYMIiWG0nyAI1F
#
#                                                      name  popularity  \
# 546130       Newspaper Reports On Abner, 20 February 1935           0
# 546222                                             恋は水の上で           0
# 546221                                              私の誕生日           0
# 546220                                エル・チョクロ (EL CHOCLO)           0
# 546219                                           恋は不思議なもの           0
# 546218                         ゆうべはどうしたの (WHATSA MALLA U)           0
# 546217  Screen Director's Playhouse, Music For Million...           0
# ...

# %%
Data
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %%
column1 = 'duration_ms'
column2 = 'popularity'


correlation = Data[column1].corr(Data[column2])

print(f"Correlation between '{column1}' and '{column2}': {correlation}")
# Out:
#                            id  \
# 93802  4iJyoBOLtHqaGxP12qzhQI
# 93803  7lPN2DXiMsVn7XUKtOW1CS
# 93804  3Ofmpyhv5UAQ70mENzB277
# 92810  5QO79kh1waicV47BqGRL3g
# 92811  6tDDoYIxWvMLTdKpjFkc1B
# 93805  7MAibcTli4IisCtbHKrGMh
# 92813  0VjIjW4GlUZAMYd2vXMi3b
# 92814  6f3Slt0GbA2bPZlz0aIFXN
# 92816  3FAJ6O0NOHQV8Mc5Ri6ENp
# 92819  1xK1Gg9SxG8fy2Ya373oqb
# 93807  4cG7HUWYHBV6R6tHn1gxrl
# 93806  7Bk0uXKk1uPT0XuQbpFzvs
# 91866  60ynsPSSKe6O3sfwRnIBRf
# 92817  27OeeYzk6klgBh83TSvGMA
# 92823  3YJJjQPAbDT7mGpX3WtQ9A
# 92821  2XIc1pqjXV3Cr2BQUGNBck
# 93812  3iw6V4LH7yPj1ESORX9RIN
# 92824  47EiUVwUp4C9fGccaPuUCS
# 92826  35mvY5S1H3J2QZyna3TFe0
# 92827  3VvA1wSxukMLsvXoXtlwWx
#
#                                                     name  popularity  \
# 93802             Peaches (feat. Daniel Caesar & Giveon)         100
# 93803                                    drivers license          99
# 93804                             Astronaut In The Ocean          98
# ...

# %%
# correlation between duration and popularity of songs. A correlation of 0,027 is a positive but very week correlation, closer to 0 than it is to 1, 0 being no correlation.
column1 = 'duration_ms'
column2 = 'popularity'


correlation = Data[column1].corr(Data[column2])

print(f"Correlation between '{column1}' and '{column2}': {correlation}")
# Out:
# Correlation between 'duration_ms' and 'popularity': 0.027680666048806486

# %%
#visualization
plt.figure(figsize=(8, 6))
plt.scatter(Data[column1], Data[column2], alpha=0.5, color='blue')
plt.title(f'Scatter Plot of {column1} vs {column2}')
plt.xlabel(column1)
plt.ylabel(column2)
plt.grid(True)
plt.show()

# %%
# To sort the Data table taking into account "population", putting it in ascending=false which means from the largest to the smallest, only for the top 20 to have less points and visualize the correlation better
sorted_popularity= Data.sort_values('popularity', ascending=False)
top_20=sorted_popularity.head(20)
top_20
# Out:
#                            id  \
# 93802  4iJyoBOLtHqaGxP12qzhQI
# 93803  7lPN2DXiMsVn7XUKtOW1CS
# 93804  3Ofmpyhv5UAQ70mENzB277
# 92810  5QO79kh1waicV47BqGRL3g
# 92811  6tDDoYIxWvMLTdKpjFkc1B
# 93805  7MAibcTli4IisCtbHKrGMh
# 92813  0VjIjW4GlUZAMYd2vXMi3b
# 92814  6f3Slt0GbA2bPZlz0aIFXN
# 92816  3FAJ6O0NOHQV8Mc5Ri6ENp
# 92819  1xK1Gg9SxG8fy2Ya373oqb
# 93807  4cG7HUWYHBV6R6tHn1gxrl
# 93806  7Bk0uXKk1uPT0XuQbpFzvs
# 91866  60ynsPSSKe6O3sfwRnIBRf
# 92817  27OeeYzk6klgBh83TSvGMA
# 92823  3YJJjQPAbDT7mGpX3WtQ9A
# 92821  2XIc1pqjXV3Cr2BQUGNBck
# 93812  3iw6V4LH7yPj1ESORX9RIN
# 92824  47EiUVwUp4C9fGccaPuUCS
# 92826  35mvY5S1H3J2QZyna3TFe0
# 92827  3VvA1wSxukMLsvXoXtlwWx
#
#                                                     name  popularity  \
# 93802             Peaches (feat. Daniel Caesar & Giveon)         100
# 93803                                    drivers license          99
# 93804                             Astronaut In The Ocean          98
# ...

# %%
#correlation
column1 = 'duration_ms'
column2 = 'popularity'


correlation = top_20[column1].corr(top_20[column2])

print(f"Correlation between '{column1}' and '{column2}': {correlation}")
# Out:
# Correlation between 'duration_ms' and 'popularity': 0.04611248791121051

# %%
#visualization
plt.figure(figsize=(8, 6))
plt.scatter(top_20[column1], top_20[column2], alpha=0.5, color='blue')
plt.title(f'Scatter Plot of {column1} vs {column2}')
plt.xlabel(column1)
plt.ylabel(column2)
plt.grid(True)
plt.show()

# %%
# the top_20 variable as been developed and visualized to see if the duration had a more import impact on a song's popalrity when approaching the top 20. The correlation is slighly higher compared to when taking the whole data sheet, but it might simply be due to the fact that the top20 is using less data so less dispersion, not really a noticeable change.

# %%
Data.describe().transpose()
# Out:
#                      count           mean            std     min          25%  \
# popularity        586672.0      27.570053      18.370642     0.0      13.0000
# duration_ms       586672.0  230051.167286  126526.087418  3344.0  175093.0000
# explicit          586672.0       0.044086       0.205286     0.0       0.0000
# danceability      586672.0       0.563594       0.166103     0.0       0.4530
# energy            586672.0       0.542036       0.251923     0.0       0.3430
# key               586672.0       5.221603       3.519423     0.0       2.0000
# loudness          586672.0     -10.206067       5.089328   -60.0     -12.8910
# mode              586672.0       0.658797       0.474114     0.0       0.0000
# speechiness       586672.0       0.104864       0.179893     0.0       0.0340
# acousticness      586672.0       0.449863       0.348837     0.0       0.0969
# instrumentalness  586672.0       0.113451       0.266868     0.0       0.0000
# ...

# %%
#1-select only rows where popularity >90
#2- Arrange it in order by popuarity, in a descending way (ascending=False) which means bigger to lower

most_popular = Data.loc[Data["popularity"]>90].sort_values('popularity', ascending=False)

#or

most_popular = Data.query("popularity>90", inplace= False).sort_values('popularity', ascending=False)
most_popular
# Out:
#                            id  \
# 93802  4iJyoBOLtHqaGxP12qzhQI
# 93803  7lPN2DXiMsVn7XUKtOW1CS
# 93804  3Ofmpyhv5UAQ70mENzB277
# 92810  5QO79kh1waicV47BqGRL3g
# 92811  6tDDoYIxWvMLTdKpjFkc1B
# 92813  0VjIjW4GlUZAMYd2vXMi3b
# 93805  7MAibcTli4IisCtbHKrGMh
# 92814  6f3Slt0GbA2bPZlz0aIFXN
# 91866  60ynsPSSKe6O3sfwRnIBRf
# 92816  3FAJ6O0NOHQV8Mc5Ri6ENp
# 92817  27OeeYzk6klgBh83TSvGMA
# 92819  1xK1Gg9SxG8fy2Ya373oqb
# 93807  4cG7HUWYHBV6R6tHn1gxrl
# 93806  7Bk0uXKk1uPT0XuQbpFzvs
# 92821  2XIc1pqjXV3Cr2BQUGNBck
# 92823  3YJJjQPAbDT7mGpX3WtQ9A
# 93812  3iw6V4LH7yPj1ESORX9RIN
# 93810  5uEYRdEIh9Bo4fpjDd4Na9
# 93811  4u4NyuceXP7Uzh7XFJKCr1
# 92829  6ft4hAq6yde8jPZY2i5zLr
# 91867  6UelLqGlWMcVH1E5c4H7lY
# 93809  1XXimziG1uhM0eDNCZCrUl
# 92827  3VvA1wSxukMLsvXoXtlwWx
# 92826  35mvY5S1H3J2QZyna3TFe0
# 92824  47EiUVwUp4C9fGccaPuUCS
# 93808  5YYW3yRktprLRr47WK219Y
# 93813  2TksvaRivgAEj780DgRB73
# 93814  5YaskwnGDZFDRipaqzbwQx
# 93815  3aQem4jVGdhtg116TmJnHz
# 92835  6Im9k8u9iIzKMrmV7BWtlF
# ...

# %%
Select= Data.loc [Data['name']== "What You Know Bout Love"]
Select
# Out:
#                             id                     name  popularity  \
# 92841   1tkg4EHVoqnhR6iFEXb60y  What You Know Bout Love          91
# 159194  1itoX48UFbINWK9ls5IKoV  What You Know Bout Love          22
# 159195  2pSx4Sn0MNaJmwALSs6xUe  What You Know Bout Love          16
# 159199  3gTSOT5ADyhDanDt9eBBGA  What You Know Bout Love           6
# 159202  7GpojLvZTFBEO7AGFsy3nG  What You Know Bout Love           6
# 159203  7KV3HHTWMtojhqtSzS2jtP  What You Know Bout Love           0
# 178540  3sstHCWtNTjbrf4KIYck0k  What You Know Bout Love          25
# 178541  2q9zBAWi5FqWleTel551dM  What You Know Bout Love          24
# 178543  2P4InWgPJaGPGqfhNSbaFX  What You Know Bout Love          19
# 178544  4GCH3EIxsOhzJ36yaktcV1  What You Know Bout Love          16
# 178545  7KkenbenwMSk66VvABmQHb  What You Know Bout Love          11
# 481510  22aPjlNFZG53tqBQtUCEq4  What You Know Bout Love          17
# 576125  6ILjkEufgyZ7NyLnrpr6zr  What You Know Bout Love           0
#
# ...

# %%
#after getting the whole data set of a song by indexing the name, we found out that the song "What you know Bout Love" is present 13 times in the data frame, but at different level of poplarity, explain ideas of why

song_count= (Data['name']== "What You Know Bout Love").sum()
song_count
# Out:
# 13

# %%
# We are getting rid of duplicate names from the data sheet
Data_unique= Data.drop_duplicates(subset="name")
Data_unique
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586665  0SjsIzJkZfDU7wlcdklEFR                    John Brown's Song
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %%
#Checking if we no more have duplicates

duplicate_names = Data_unique['name'].duplicated()


if duplicate_names.any():
    print("Duplicate names found in the DataFrame.")
else:
    print("No duplicate names found in the DataFrame.")
# Out:
# No duplicate names found in the DataFrame.

# %%
Select= Data_unique.loc [Data_unique['name']== "What You Know Bout Love"]
Select
# Out:
#                            id                     name  popularity  \
# 92841  1tkg4EHVoqnhR6iFEXb60y  What You Know Bout Love          91
#
#        duration_ms  explicit        artists                  id_artists  \
# 92841       160000         1  ['Pop Smoke']  ['0eDvMgVFoNV3TpwtrVCoTj']
#
#       release_date  danceability  energy  key  loudness  mode  speechiness  \
# 92841   2020-07-03         0.709   0.548   10    -8.493     1        0.353
#
#        acousticness  instrumentalness  liveness  valence   tempo  \
# 92841          0.65          0.000002     0.133    0.543  83.995
#
#        time_signature
# 92841               4

# %%
# Several ways to explain why the same song may be there several times, maybe data entry redundancy. Here, it might simply be the fact that the same song is being reuploaded on the platform with different covers on different accounts that aren't the main account, giving a dataframe where we have the original version which is allows the one with the oldest date, and the rest being reuploads from other accounts with therefore less popularity. It's also a cause of why duration & song popularity aren't correlating that much especially here. Being from an official account or tier account reupload plays too.

# %%
#let's recalculate correlation now that we don't have duplicated songs anymore, Data_unique is the new dataframe to use now.

column1 = 'duration_ms'
column2 = 'popularity'


correlation = Data_unique[column1].corr(Data_unique[column2])

print(f"Correlation between '{column1}' and '{column2}': {correlation}")
# Out:
# Correlation between 'duration_ms' and 'popularity': 0.025232956564345377

# %%
#The correlation is even lower than test1 with the redundancy and the full dataframe, and test2 with the top20 songs in popularity, the conclusion is therefore clearly there is no correlation, no matter how we turn the data around.

# %%
#Data manipulation, here we are changing the duration from milliseconds to seconds

Data["duration"]= Data["duration_ms"].apply(lambda x: round(x/1000))
Data.drop ("duration_ms", inplace=True, axis=1)

# %%
Data
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  explicit                          artists  \
# 0                6         0                          ['Uli']
# ...

# %%
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586665  0SjsIzJkZfDU7wlcdklEFR                    John Brown's Song
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
#
#         popularity  explicit                          artists  \
# 0                6         0                          ['Uli']
# ...

# %%
duplicate_names = Data['name'].duplicated()


if duplicate_names.any():
    print("Duplicate names found in the DataFrame.")
else:
    print("No duplicate names found in the DataFrame.")
# Out:
# Duplicate names found in the DataFrame.

# %%
Data_unique.name.head()
# Out:
# 0                                  Carve
# 1    Capítulo 2.16 - Banquero Anarquista
# 2     Vivo para Quererte - Remasterizado
# 3          El Prisionero - Remasterizado
# 4                    Lady of the Evening
# Name: name, dtype: object

# %%
#correlation complete with all the variables

correlation= Data_unique.drop (["key", "mode", "explicit"], axis=1).corr(method="pearson")
plt.figure(figsize=(14,6))
heatmap=sns.heatmap(correlation, annot=True, fmt= ".1g", vmin=-1, vmax=1, center=0, cmap="inferno", linewidths =1, linecolor="Black")
heatmap.set_title("correlation between indexes/variables using heatmap")
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=90)
# Out:
# <ipython-input-29-64cf43252121>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation= Data_unique.drop (["key", "mode", "explicit"], axis=1).corr(method="pearson")
# [Text(0.5, 0, 'popularity'),
#  Text(1.5, 0, 'danceability'),
#  Text(2.5, 0, 'energy'),
#  Text(3.5, 0, 'loudness'),
#  Text(4.5, 0, 'speechiness'),
#  Text(5.5, 0, 'acousticness'),
#  Text(6.5, 0, 'instrumentalness'),
#  Text(7.5, 0, 'liveness'),
#  Text(8.5, 0, 'valence'),
#  Text(9.5, 0, 'tempo'),
#  Text(10.5, 0, 'time_signature'),
#  Text(11.5, 0, 'duration')]

# %%
#We are taking 0.004 of the whole data frame for an analysis

sample1= Data_unique.sample(int(0.004*len(Data_unique)))
print(len(sample1))
# Out:
# 1785

# %%
#scatterplot with right. Here we have a positive and strong correlation.

plt.figure(figsize=(10,6))
sns.regplot (data = sample1, y="loudness", x="energy", color="c").set(title = "Corrlation loudness - energy")
# Out:
# [Text(0.5, 1.0, 'Corrlation loudness - energy')]

# %%
Data
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %%
Data["Dates"] = pd.to_datetime(Data["release_date"])
years=Data.Dates.dt.year

# %%
sns.displot (years, discrete=True, aspect=2, height=5, kind="hist"). set(title="Number of song per year")

# %%
cleaned_data.to_csv('cleaned_data.csv', index=False)
